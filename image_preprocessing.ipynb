# %%
import os
from glob import glob
INPUT_DIR = "C:/Users/anjal/Documents/733BDLab2/git-repo/cmpt733-deepfake-detection/deepfake-detection-challenge/train_sample_videos"
videopaths = sorted(glob(os.path.join(INPUT_DIR, "*.mp4")))
print("Number of videos:", len(videopaths))
# Out:
# Number of videos: 244

# %%
pip install opencv-python

# %%
conda install pytorch torchvision cudatoolkit=10.2 -c pytorch
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras==2.1.5

# %%
import cv2
import matplotlib.pylab as plt
from facenet_pytorch import MTCNN
from PIL import Image

# %%
v_cap = cv2.VideoCapture(videopaths[0])
_, frame = v_cap.read()
frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
frame = Image.fromarray(frame)

plt.figure(figsize=(12, 8))
plt.imshow(frame)
plt.axis('off')


mtcnn = MTCNN(select_largest=False, keep_all=True, post_process=False)#select_largest=False, device='cuda')
#result = mtcnn.detect(frame)
#print(result)
face = mtcnn(frame)
print(face.shape)
# Out:
# torch.Size([3, 160, 160])

# %%
plt.imshow(face.permute(1, 2, 0).int().numpy())
plt.axis('off')
# Out:
# (-0.5, 159.5, 159.5, -0.5)
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\anjal\anaconda3
#
#   added / updated specs:
#     - cudatoolkit=10.2
#     - pytorch
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-10.2.89        |       h74a9793_1       317.2 MB
#     libuv-1.40.0               |       he774522_0         255 KB
#     ninja-1.10.2               |   py38h6d14046_0         247 KB
#     pytorch-1.8.0              |py3.8_cuda10.2_cudnn7_0       858.0 MB  pytorch
#     torchvision-0.9.0          |       py38_cu102         7.3 MB  pytorch
#     ------------------------------------------------------------
#                                            Total:        1.16 GB
#
# The following NEW packages will be INSTALLED:
#
# ...
